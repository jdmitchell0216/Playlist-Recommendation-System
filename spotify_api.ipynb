# %% [markdown]
# [Spotify API Search](https://developer.spotify.com/documentation/web-api/reference/search/search/)

# %%
from __future__ import print_function    # (at top of module)
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import time
import sys
import pandas as pd
import numpy as np
import re

# %%
# %load_ext dotenv
# %dotenv

# %%
import os
cid = os.environ.get('SPOTIPY_CLIENT_ID')
secret = os.environ.get('SPOTIPY_CLIENT_SECRET')
username = os.environ.get('SPOTIFY_USER_ID')
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)     
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def users_to_playlists(users):
    playlists = []
    for user in users:
        try:
            for item in sp.user_playlists(user)['items']:
                try:
                    playlists.append({'user_id':user, 'playlist_id':item['id'], 'added_by_id':item['owner']['id']})
                except:
                    print('except playlist')
        except:
            print('except user')
        print('user_complete')
    return playlists

# %%
def parse_playlist_data(userID, playlistID, limit = 100, fields = 'items,total,next'):
    '''
    Used to get information about the tracks in spotify playlist
    
    Arguments:
    userID is a spotify user ID
    playlistID is a spotify playlist ID
    limit is the number of tracks to retrieve in each call. "Next" is used to get all songs. 100 is the max to
        retrieve at once
    fields is the fields to retrieve for each playlist call
    
    Returns:
    A 2D list where each row is a dictionary corresponding to a song
    the keys of this dictionary are: user_id, playlist_id, added_by_id, album_name,
                album_id, artist_names, artist_ids, track_name, track_id, date_added
    '''
    playlist = sp.user_playlist_tracks(userID,
                            playlist_id=playlistID,
                            fields = fields,
                            limit = limit)
    test_data_list = []
    for i in range(len(playlist['items'])):
        artist_name_list = []
        artist_id_list = []
        added_by_id = playlist['items'][i]['added_by']['id']
        added_at = playlist['items'][i]['added_at']
        curr = playlist['items'][i]['track']
        for j in range(len(curr['artists'])):
            artist_name_list.append(curr['artists'][j]['name'])
            artist_id_list.append(curr['artists'][j]['id'])
        track_name = curr['name']
        track_id = curr['id']
        album_name = curr['album']['name']
        album_id = curr['album']['id']
        test_data_list.append({'user_id': userID,
                               'playlist_id': playlistID,
                               'added_by_id': added_by_id,
                               'album_name': album_name,
                               'album_id': album_id,
                               'artist_names':artist_name_list,
                               'artist_ids':artist_id_list,
                               'track_name': track_name,
                               'track_id': track_id,
                               'date_added': added_at
                              })
    while playlist['next']:
        playlist = sp.next(playlist)
        for i in range(len(playlist['items'])):
            artist_name_list = []
            artist_id_list = []
            added_by_id = playlist['items'][i]['added_by']['id']
            added_at = playlist['items'][i]['added_at']
            curr = playlist['items'][i]['track']
            for j in range(len(curr['artists'])):
                artist_name_list.append(curr['artists'][j]['name'])
                artist_id_list.append(curr['artists'][j]['id'])
            track_name = curr['name']
            track_id = curr['id']
            album_name = curr['album']['name']
            album_id = curr['album']['id']
            test_data_list.append({'user_id': userID,
                                   'playlist_id': playlistID,
                                   'added_by_id': added_by_id,
                                   'album_name': album_name,
                                   'album_id': album_id,
                                   'artist_names':artist_name_list,
                                   'artist_ids':artist_id_list,
                                   'track_name': track_name,
                                   'track_id': track_id,
                                   'date_added': added_at
                                  })
    return test_data_list

# %%
df = pd.read_json('users_9_15_19.json')

# %%
df.shape
# Out:
# (428, 1)

# %%
users = list(df[0])

# %%
playlists = users_to_playlists(users)
# Out:
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# except user
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# except user
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# except user
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# except user
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete
# user_complete

# %%
df_playlists = pd.DataFrame(playlists)

# %%
df_playlists.shape
# Out:
# (8562, 3)

# %%
df_playlists.to_json('playlists_9_18_19.json')

# %%
df_playlists.head()
# Out:
#   added_by_id             playlist_id    user_id
# 0   technozem  5tW6vGqn4Z2oPxpgQSncKD  technozem
# 1   technozem  2zDMz1GFzSpjHT7kU4Sjqr  technozem
# 2   technozem  4085JGoRIJkqXboXz9Qnuw  technozem
# 3   technozem  0K3Z661zDkEstO4sVclqiY  technozem
# 4   technozem  4AehzXKZqJ5VrqPHpsmN6E  technozem

# %%
df_playlists[df_playlists.added_by_id != df_playlists.user_id].shape
# Out:
# (1066, 3)

# %%
playlist_curr = list(df_playlists.playlist_id)
user_curr = list(df_playlists.user_id)
feed = list(zip(user_curr, playlist_curr))

# %%
track_data = []
for user, playlist in feed:
    try:
        track_data.append(parse_playlist_data(user, playlist))
    except Exception as e:
        print(e)
# Out:
# 'NoneType' object is not subscriptable
# 'artists'
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# http status: 404, code:-1 - https://api.spotify.com/v1/users/1243463050/playlists/37i9dQZF1E4kfGdEIPByvv/tracks?limit=100&offset=0&fields=items%2Ctotal%2Cnext:
#  Not found.
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'artists'
# 'artists'
# 'NoneType' object is not subscriptable
# 'artists'
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# retrying ...1secs

# %%
len(track_data)
# Out:
# 8538

# %%
pd.DataFrame(track_data).to_json('track_data_9_18_19.json')

# %%
pd.DataFrame(track_data).head()
# Out:
#                                                 0     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 1     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 2     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 3     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 4     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 5     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 6     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 7     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 8     \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...
#
#                                                 9     ...  9990  9991  9992  \
# 0  {'user_id': 'technozem', 'playlist_id': '5tW6v...  ...  None  None  None
# 1  {'user_id': 'technozem', 'playlist_id': '2zDMz...  ...  None  None  None
# 2  {'user_id': 'technozem', 'playlist_id': '4085J...  ...  None  None  None
# 3  {'user_id': 'technozem', 'playlist_id': '0K3Z6...  ...  None  None  None
# 4  {'user_id': 'technozem', 'playlist_id': '4Aehz...  ...  None  None  None
#
#    9993  9994  9995  9996  9997  9998  9999
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 10000 columns]

# %%
new_list = sum(track_data,[])

# %%
df_all_test = pd.DataFrame(new_list)

# %%
df_all_test.head()
# Out:
#   added_by_id                album_id    album_name  \
# 0   technozem  0d0ONE5rak6Q91XjwKcJvN       Vurstep
# 1   technozem  2qz8u01gOb8Lb7KaTR90DQ        Marble
# 2   technozem  0MhqzH66vEpY9fXdEz2zV4         Named
# 3   technozem  0C8vASB72lAeufmEymy0G4    Dull Clunk
# 4   technozem  79c2iZmw26LF2jhafHQPIl  Sick Parrots
#
#                                          artist_ids  \
# 0  [7ugvHO0W3IoAWzOgKrHxqr, 0K1lHu1BP65Z1DErnljxUw]
# 1  [7asRTH6SKIMKZZ59Iw2eA5, 2iWOFT9U8InefnarwZUmv0]
# 2                          [7d51SgJwoUOPISsskT0lD4]
# 3                          [4n9YVkzW4gl64xbOSLqeEl]
# 4                          [6YlLUbef5d4ptmxkMKsrlK]
#
#                      artist_names            date_added  \
# 0  [Appleblim, Forest Drive West]  2018-12-04T21:27:55Z
# 1                 [Gnork, Douala]  2018-12-12T21:33:25Z
# 2                           [EOD]  2018-12-05T10:18:36Z
# 3                        [Garies]  2018-12-27T20:30:53Z
# 4                        [Voiski]  2018-12-12T07:38:36Z
#
#               playlist_id                track_id  \
# 0  5tW6vGqn4Z2oPxpgQSncKD  5huzNc7H2kv2qNq7kqscHY
# 1  5tW6vGqn4Z2oPxpgQSncKD  7Hhfn4AkePvX0jW4jOJPQ3
# 2  5tW6vGqn4Z2oPxpgQSncKD  34QLCZF2VtlHLPNkTH58bZ
# 3  5tW6vGqn4Z2oPxpgQSncKD  5dE3OUB3RhccA3dNhxc3OW
# 4  5tW6vGqn4Z2oPxpgQSncKD  6aMvQmtQKOPTc022sDM0Tv
#
#                           track_name    user_id
# 0  Vurstep - Forest Drive West Remix  technozem
# 1           Space Jam (feat. Douala)  technozem
# 2        Exham Priory - Original Mix  technozem
# 3                   Modified By This  technozem
# 4                          Blue Flag  technozem

# %%
df_all_test = pd.read_json('track_data_9_18_19.json')

# %%
df_all_test.head()
# Out:
#      added_by_id                album_id  \
# 0      technozem  0d0ONE5rak6Q91XjwKcJvN
# 1      technozem  2qz8u01gOb8Lb7KaTR90DQ
# 10     technozem  4JooAi5hHhUuJNrbiseE8X
# 100    technozem  6fXNAGf1ihG0B0Sck2Mo1l
# 1000   technozem  3YQASaeJPm3OxUSCP6Qfo9
#
#                                   album_name  \
# 0                                    Vurstep
# 1                                     Marble
# 10                           At the Controls
# 100                               Metropolis
# 1000  GROEF - Des avonds in klein maneschijn
#
#                                             artist_ids  \
# 0     [7ugvHO0W3IoAWzOgKrHxqr, 0K1lHu1BP65Z1DErnljxUw]
# 1     [7asRTH6SKIMKZZ59Iw2eA5, 2iWOFT9U8InefnarwZUmv0]
# 10                            [68Wb5Pcy71lLaKdIB6cBA5]
# 100                           [0Ij7th9uWcDVYNAIOn5W22]
# 1000                          [7DksXfhuJLdqtyHnoKCJLI]
#
#                         artist_names            date_added  \
# 0     [Appleblim, Forest Drive West]  2018-12-04T21:27:55Z
# 1                    [Gnork, Douala]  2018-12-12T21:33:25Z
# 10                        [Breakage]  2018-12-11T20:02:07Z
# 100                  [Kornél Kovács]  2018-12-29T17:28:10Z
# 1000                         [GROEF]  2011-04-15T16:06:11Z
#
#                  playlist_id                track_id  \
# 0     5tW6vGqn4Z2oPxpgQSncKD  5huzNc7H2kv2qNq7kqscHY
# 1     5tW6vGqn4Z2oPxpgQSncKD  7Hhfn4AkePvX0jW4jOJPQ3
# 10    5tW6vGqn4Z2oPxpgQSncKD  5NLRRESuSXLQTPgdqAECCq
# 100   5tW6vGqn4Z2oPxpgQSncKD  0ajH7MyTiRhjUbZVYVgRPc
# 1000  4AehzXKZqJ5VrqPHpsmN6E  6sihMoVzSFhHtr2p556f5Z
#
#                              track_name    user_id  \
# 0     Vurstep - Forest Drive West Remix  technozem
# 1              Space Jam (feat. Douala)  technozem
# 10                        Rudeboy Stuff  technozem
# 100                               Panda  technozem
# 1000    Jan mijne man/Andro/Andro GROEF  technozem
#
#                        artists_join  \
# 0     Appleblim___Forest Drive West
# 1                    Gnork___Douala
# 10                         Breakage
# 100                   Kornél Kovács
# 1000                          GROEF
#
#                                        artist_and_track  rating
# 0     Appleblim___Forest Drive West|||||Vurstep - Fo...       1
# 1           Gnork___Douala|||||Space Jam (feat. Douala)       1
# 10                           Breakage|||||Rudeboy Stuff       1
# 100                             Kornél Kovács|||||Panda       1
# 1000          GROEF|||||Jan mijne man/Andro/Andro GROEF       1

# %%
df_all_test['rating'] = 1

# %%
df_all_test['artists_join'] = df_all_test.artist_names.apply(lambda x: '___'.join(x))

# %%
df_all_test['artist_and_track'] = df_all_test.artists_join + '|||||' + df_all_test.track_name

# %%
df_all_test = df_all_test[df_all_test.duplicated(subset='artist_and_track', keep=False)] # run to get rid of songs that only occur once

# %%
df_all_test.head()
# Out:
#      added_by_id                album_id  \
# 0      technozem  0d0ONE5rak6Q91XjwKcJvN
# 1      technozem  2qz8u01gOb8Lb7KaTR90DQ
# 10     technozem  4JooAi5hHhUuJNrbiseE8X
# 100    technozem  6fXNAGf1ihG0B0Sck2Mo1l
# 1000   technozem  3YQASaeJPm3OxUSCP6Qfo9
#
#                                   album_name  \
# 0                                    Vurstep
# 1                                     Marble
# 10                           At the Controls
# 100                               Metropolis
# 1000  GROEF - Des avonds in klein maneschijn
#
#                                             artist_ids  \
# 0     [7ugvHO0W3IoAWzOgKrHxqr, 0K1lHu1BP65Z1DErnljxUw]
# 1     [7asRTH6SKIMKZZ59Iw2eA5, 2iWOFT9U8InefnarwZUmv0]
# 10                            [68Wb5Pcy71lLaKdIB6cBA5]
# 100                           [0Ij7th9uWcDVYNAIOn5W22]
# 1000                          [7DksXfhuJLdqtyHnoKCJLI]
#
#                         artist_names            date_added  \
# 0     [Appleblim, Forest Drive West]  2018-12-04T21:27:55Z
# 1                    [Gnork, Douala]  2018-12-12T21:33:25Z
# 10                        [Breakage]  2018-12-11T20:02:07Z
# 100                  [Kornél Kovács]  2018-12-29T17:28:10Z
# 1000                         [GROEF]  2011-04-15T16:06:11Z
#
#                  playlist_id                track_id  \
# 0     5tW6vGqn4Z2oPxpgQSncKD  5huzNc7H2kv2qNq7kqscHY
# 1     5tW6vGqn4Z2oPxpgQSncKD  7Hhfn4AkePvX0jW4jOJPQ3
# 10    5tW6vGqn4Z2oPxpgQSncKD  5NLRRESuSXLQTPgdqAECCq
# 100   5tW6vGqn4Z2oPxpgQSncKD  0ajH7MyTiRhjUbZVYVgRPc
# 1000  4AehzXKZqJ5VrqPHpsmN6E  6sihMoVzSFhHtr2p556f5Z
#
#                              track_name    user_id  rating  \
# 0     Vurstep - Forest Drive West Remix  technozem       1
# 1              Space Jam (feat. Douala)  technozem       1
# 10                        Rudeboy Stuff  technozem       1
# 100                               Panda  technozem       1
# 1000    Jan mijne man/Andro/Andro GROEF  technozem       1
#
#                        artists_join  \
# 0     Appleblim___Forest Drive West
# 1                    Gnork___Douala
# 10                         Breakage
# 100                   Kornél Kovács
# 1000                          GROEF
#
#                                        artist_and_track
# 0     Appleblim___Forest Drive West|||||Vurstep - Fo...
# 1           Gnork___Douala|||||Space Jam (feat. Douala)
# 10                           Breakage|||||Rudeboy Stuff
# 100                             Kornél Kovács|||||Panda
# 1000          GROEF|||||Jan mijne man/Andro/Andro GROEF

# %%
# df_all_test.to_json('track_data_9_18_19.json')

# %%
df_all_test = pd.read_json('track_data_9_18_19.json')

# %%
df_all_test.shape
# Out:
# (1022972, 10)

# %%
df_all_test.track_id.nunique()
# Out:
# 497590

# %%
track_counts = df_all_test.track_id.value_counts()

# %%
track_counts
# Out:
# 00HMEiBMDkbNCHLJL6zqVk    422
# 2374M0fQpWi3dLnB54qaLX    409
# 24CXuh2WNpgeSYUOvz14jk    168
# 2xLMifQCjDGFmkHkpNLD9h    155
# 0bYg9bo50gSsH3LtXe2SQn    143
# 2Fxmhks0bxGSBdJ92vM42m    138
# 7w87IxuO7BDcJ3YUqCyMTT    114
# 7ycWLEP1GsNjVvcjawXz3z    112
# 7dt6x5M1jzdTEt8oCbisTK    111
# 7sO5G9EABYOXQKNPNiE9NR    110
# 6K4t31amVTZDgR3sKmwUJJ    110
# 2JvzF1RMd7lE3KmFlsyZD8    110
# 40riOy7x9W7GXjyGp4pjAv    109
# 3FtYbEfBqAlGO46NUDQSAt    106
# 4qKcDkK6siZ7Jp1Jb4m0aL    106
# 1jJci4qxiYcOHhQR247rEU    106
# 6MWtB6iiXyIwun0YzU6DFP    103
# 7m9OqQk4RVRkw9JJdeAw96    103
# 3KkXRkHbMCARz0aVfEt68P    101
# 2IRZnDFmlqMuOrYOLnZZyc    101
# 08mG3Y1vljYA6bvDt4Wqkj    101
# 0I3q5fE6wg7LIfHGngUTnV    101
# 6gBFPUFcJLzWGx4lenP6h2    101
# 2dpaYNEQHiRxtZbfNsse99    100
# 0d28khcov6AiegSCpG5TuT     99
# 7DcvwMAiqKJQD1rrdfxSDx     99
# 5hVghJ4KaYES3BFUATCYn0     95
# 2aoo2jlRnM3A0NyLQqMN2f     94
# 7BKLCZ1jbUBVqRi2FVlTVw     92
# 2WfaOiMkCvy7F5fcp2zZ8L     91
#                          ...
# 4GVyG4iljpmVOt1CR367o7      1
# 1X2npDWQpg9lvM8MOw2mqm      1
# 7x40qXAXv4e8E0lB4rZLfH      1
# 6rXNgtYOHBW2C2KltSkeUN      1
# 7xsPTxJqmNmQPPzBhhvt09      1
# 25C5Qjkl3n2U81sCNx9R2y      1
# 2W1NZwVBN77hf2CEKFKsig      1
# 7jmYHIg5WnIKxU65APbzNU      1
# 6wlOciyEdLDqZXlloy2Fmp      1
# 03EZrYPqhjFQ4BjvDvrTrT      1
# 5qsQdS6kU9LkFY7WHFkgdM      1
# 3JWBKVY4FJTzDpBWEcYMWs      1
# 2hGioPkwOmpkE0y4hYUL4d      1
# 2bbyFfqpIzUKD1Ynl5zyix      1
# 5eyMdaZLwLE1miF5F60k3X      1
# 5omjTeGQyQYTCniU170tnA      1
# 337mFk5TSrelPRhhcGSvoq      1
# 2CsB3y2O9XdqfOvdVQSFkz      1
# 0hOrWIPARGR4bSzboe8OuA      1
# 2OdSLGGdyAqa0u076C1ru9      1
# 1bQiI5Vv6h8E8tM4qgxvcy      1
# 3nn7OPFCwHblA3BUIip8gd      1
# 0ZBeKN5Wfncs7kPRWnuDDF      1
# 4VUF7RDPHlI6RB10MdRxU9      1
# 4KfoSJ6NQoi85q9c4qk2we      1
# 4znipOw4GGtcVWFS9W1IMK      1
# 1UYrZMEDphdMFlPknI0vTR      1
# 369sRUS7c6qfils7xpAwRt      1
# 1DHxmON5ej2sda79hSlE9Z      1
# 5taUV8kbsjppc3Krz3KgFr      1
# Name: track_id, Length: 497590, dtype: int64

# %%
frequent_tracks.index
# Out:
# Index(['0bYg9bo50gSsH3LtXe2SQn', '2xLMifQCjDGFmkHkpNLD9h',
#        '2JvzF1RMd7lE3KmFlsyZD8', '2374M0fQpWi3dLnB54qaLX',
#        '40riOy7x9W7GXjyGp4pjAv', '7sO5G9EABYOXQKNPNiE9NR',
#        '7w87IxuO7BDcJ3YUqCyMTT', '2dpaYNEQHiRxtZbfNsse99',
#        '7ycWLEP1GsNjVvcjawXz3z', '2IRZnDFmlqMuOrYOLnZZyc',
#        '7m9OqQk4RVRkw9JJdeAw96', '2Fxmhks0bxGSBdJ92vM42m',
#        '7dt6x5M1jzdTEt8oCbisTK', '4qKcDkK6siZ7Jp1Jb4m0aL',
#        '6gBFPUFcJLzWGx4lenP6h2', '1LzNfuep1bnAUR9skqdHCK',
#        '08mG3Y1vljYA6bvDt4Wqkj', '1jJci4qxiYcOHhQR247rEU',
#        '0rTV5WefWd1J3OwIheTzxM', '2aoo2jlRnM3A0NyLQqMN2f',
#        '6MWtB6iiXyIwun0YzU6DFP', '0I3q5fE6wg7LIfHGngUTnV'],
#       dtype='object')

# %%
frequent_tracks = track_counts[track_counts > 70]

# %%
df_frequent = pd.DataFrame(frequent_tracks.index)
df_frequent.columns = ['track_id']

# %%
df_frequent = df_frequent.set_index(df_frequent.track_id)

# %%
df_frequent.rename(columns={'track_id': 'test_track_id'}, inplace=True)

# %%
all_tops = df_frequent.join(df_all_test[['track_name', 'track_id', 'artist_names']].set_index('track_id'), on = 'track_id')

# %%
df_all_working = pd.DataFrame(all_tops.apply(lambda x: pd.Series(x['artist_names']),axis=1).stack().reset_index(level=1, drop=True)).join(df_all_test[['track_name', 'track_id']].set_index('track_id'), on = 'track_id')

# %%
df_all_working.drop_duplicates()
# Out:
#                                         0  \
# track_id
# 0bYg9bo50gSsH3LtXe2SQn       Mariah Carey
# 2xLMifQCjDGFmkHkpNLD9h       Travis Scott
# 2JvzF1RMd7lE3KmFlsyZD8            J. Cole
# 2374M0fQpWi3dLnB54qaLX               Toto
# 40riOy7x9W7GXjyGp4pjAv             Eagles
# 7sO5G9EABYOXQKNPNiE9NR             Offset
# 7sO5G9EABYOXQKNPNiE9NR       Metro Boomin
# 7w87IxuO7BDcJ3YUqCyMTT  Foster The People
# 2dpaYNEQHiRxtZbfNsse99         Marshmello
# 2dpaYNEQHiRxtZbfNsse99           Bastille
# 7ycWLEP1GsNjVvcjawXz3z         A$AP Rocky
# 7ycWLEP1GsNjVvcjawXz3z             Skepta
# 2IRZnDFmlqMuOrYOLnZZyc          Meek Mill
# 2IRZnDFmlqMuOrYOLnZZyc              Drake
# 7m9OqQk4RVRkw9JJdeAw96       XXXTENTACION
# 2Fxmhks0bxGSBdJ92vM42m      Billie Eilish
# 7dt6x5M1jzdTEt8oCbisTK        Post Malone
# 4qKcDkK6siZ7Jp1Jb4m0aL         BlocBoy JB
# 4qKcDkK6siZ7Jp1Jb4m0aL              Drake
# 6gBFPUFcJLzWGx4lenP6h2       Travis Scott
# 1LzNfuep1bnAUR9skqdHCK         Mazzy Star
# 08mG3Y1vljYA6bvDt4Wqkj              AC/DC
# 1jJci4qxiYcOHhQR247rEU               MGMT
# 0rTV5WefWd1J3OwIheTzxM             Khalid
# 0rTV5WefWd1J3OwIheTzxM         Disclosure
# 2aoo2jlRnM3A0NyLQqMN2f       Jimi Hendrix
# 6MWtB6iiXyIwun0YzU6DFP        Post Malone
# 0I3q5fE6wg7LIfHGngUTnV            OutKast
#
#                                                        track_name
# track_id
# 0bYg9bo50gSsH3LtXe2SQn            All I Want for Christmas Is You
# 2xLMifQCjDGFmkHkpNLD9h                                 SICKO MODE
# 2JvzF1RMd7lE3KmFlsyZD8                               MIDDLE CHILD
# 2374M0fQpWi3dLnB54qaLX                                     Africa
# 40riOy7x9W7GXjyGp4pjAv           Hotel California - 2013 Remaster
# 7sO5G9EABYOXQKNPNiE9NR            Ric Flair Drip (& Metro Boomin)
# 7sO5G9EABYOXQKNPNiE9NR            Ric Flair Drip (& Metro Boomin)
# 7w87IxuO7BDcJ3YUqCyMTT                            Pumped Up Kicks
# 2dpaYNEQHiRxtZbfNsse99                                    Happier
# 2dpaYNEQHiRxtZbfNsse99                                    Happier
# 7ycWLEP1GsNjVvcjawXz3z  Praise The Lord (Da Shine) (feat. Skepta)
# 7ycWLEP1GsNjVvcjawXz3z  Praise The Lord (Da Shine) (feat. Skepta)
# 2IRZnDFmlqMuOrYOLnZZyc                    Going Bad (feat. Drake)
# 2IRZnDFmlqMuOrYOLnZZyc                    Going Bad (feat. Drake)
# 7m9OqQk4RVRkw9JJdeAw96                             Jocelyn Flores
# 2Fxmhks0bxGSBdJ92vM42m                                    bad guy
# 7dt6x5M1jzdTEt8oCbisTK                                 Better Now
# 4qKcDkK6siZ7Jp1Jb4m0aL                   Look Alive (feat. Drake)
# 4qKcDkK6siZ7Jp1Jb4m0aL                   Look Alive (feat. Drake)
# 6gBFPUFcJLzWGx4lenP6h2                                 goosebumps
# 1LzNfuep1bnAUR9skqdHCK                              Fade Into You
# 08mG3Y1vljYA6bvDt4Wqkj                              Back In Black
# 1jJci4qxiYcOHhQR247rEU                                       Kids
# 0rTV5WefWd1J3OwIheTzxM                                       Talk
# 0rTV5WefWd1J3OwIheTzxM                                       Talk
# 2aoo2jlRnM3A0NyLQqMN2f                   All Along the Watchtower
# 6MWtB6iiXyIwun0YzU6DFP                                       Wow.
# 0I3q5fE6wg7LIfHGngUTnV                                Ms. Jackson
